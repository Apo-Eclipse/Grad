# %% [markdown]
# # Agent Testing Notebook
#
# This notebook is designed for experimenting with and testing the functionalities of the agents in the multi-agent project. It will include code snippets to initialize agents, run tests, and visualize results.

# %%
import weaviate
from langchain_weaviate.vectorstores import WeaviateVectorStore
from langchain_core.documents import Document


client = weaviate.Client(
    url="oisg4kutbmqdibun4varg.c0.us-west3.gcp.weaviate.cloud",  # e.g., "https://my-cluster-name.weaviate.network"
    auth_client_secret=weaviate.AuthApiKey(api_key="c1BUdmxCUzlNUlRYUi90eF9XQkJZWDlhQUJTWjgwWGVtWnY4UWROSDlvNUdqd2ZMRGNqV29aOXNMR3U0PV92MjAw")
)

vector_store = WeaviateVectorStore.from_documents(
    documents = [Document(page_content="This is a sample document.", metadata={"source": "sample.txt"})],
    client=client,
    index_name="Episodic_memory",
    embedding=embeddings
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import weaviate
#       2 from langchain_weaviate.vectorstores import WeaviateVectorStore
#       3 from langchain_core.documents import Document
#
# File c:\Users\karim\AppData\Local\Programs\Python\Python312\Lib\site-packages\weaviate\__init__.py:3
#       1 from importlib.metadata import version, PackageNotFoundError
# ----> 3 from . import classes
#       5 try:
#       6     __version__ = version("weaviate")
#
# ImportError: cannot import name 'classes' from partially initialized module 'weaviate' (most likely due to a circular import) (c:\Users\karim\AppData\Local\Programs\Python\Python312\Lib\site-packages\weaviate\__init__.py)
